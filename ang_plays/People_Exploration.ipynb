# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/angie/Desktop/group_project/Chicago-Crashes/data/Traffic_Crashes_-_People.csv')
# Out:
# C:\Users\angie\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (12,13,20,21,22,23,24,25,26,27,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1195747 entries, 0 to 1195746
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   PERSON_ID              1195747 non-null  object
#  1   PERSON_TYPE            1195747 non-null  object
#  2   CRASH_RECORD_ID        1195747 non-null  object
#  3   RD_NO                  1185613 non-null  object
#  4   VEHICLE_ID             1172146 non-null  float64
#  5   CRASH_DATE             1195747 non-null  object
#  6   SEAT_NO                244512 non-null   float64
#  7   CITY                   879728 non-null   object
#  8   STATE                  890189 non-null   object
#  9   ZIPCODE                803192 non-null   object
#  10  SEX                    1177665 non-null  object
#  11  AGE                    852450 non-null   float64
#  12  DRIVERS_LICENSE_STATE  705542 non-null   object
#  13  DRIVERS_LICENSE_CLASS  608027 non-null   object
#  14  SAFETY_EQUIPMENT       1192258 non-null  object
#  15  AIRBAG_DEPLOYED        1173141 non-null  object
#  16  EJECTION               1181206 non-null  object
#  17  INJURY_CLASSIFICATION  1195154 non-null  object
#  18  HOSPITAL               215168 non-null   object
#  19  EMS_AGENCY             136061 non-null   object
#  20  EMS_RUN_NO             22281 non-null    object
#  21  DRIVER_ACTION          948962 non-null   object
#  22  DRIVER_VISION          948631 non-null   object
#  23  PHYSICAL_CONDITION     949646 non-null   object
#  24  PEDPEDAL_ACTION        22222 non-null    object
#  25  PEDPEDAL_VISIBILITY    22174 non-null    object
#  26  PEDPEDAL_LOCATION      22221 non-null    object
#  27  BAC_RESULT             950056 non-null   object
#  28  BAC_RESULT VALUE       1513 non-null     float64
#  29  CELL_PHONE_USE         1157 non-null     object
# dtypes: float64(4), object(26)
# memory usage: 273.7+ MB

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

pd.set_option('display.max_rows', None)
missing_value_df
# Out:
#                                  column_name  percent_missing
# PERSON_ID                          PERSON_ID         0.000000
# PERSON_TYPE                      PERSON_TYPE         0.000000
# CRASH_RECORD_ID              CRASH_RECORD_ID         0.000000
# RD_NO                                  RD_NO         0.847504
# VEHICLE_ID                        VEHICLE_ID         1.973745
# CRASH_DATE                        CRASH_DATE         0.000000
# SEAT_NO                              SEAT_NO        79.551527
# CITY                                    CITY        26.428584
# STATE                                  STATE        25.553733
# ZIPCODE                              ZIPCODE        32.829269
# SEX                                      SEX         1.512193
# AGE                                      AGE        28.709836
# DRIVERS_LICENSE_STATE  DRIVERS_LICENSE_STATE        40.995712
# DRIVERS_LICENSE_CLASS  DRIVERS_LICENSE_CLASS        49.150866
# SAFETY_EQUIPMENT            SAFETY_EQUIPMENT         0.291784
# AIRBAG_DEPLOYED              AIRBAG_DEPLOYED         1.890534
# EJECTION                            EJECTION         1.216060
# INJURY_CLASSIFICATION  INJURY_CLASSIFICATION         0.049592
# HOSPITAL                            HOSPITAL        82.005558
# EMS_AGENCY                        EMS_AGENCY        88.621255
# EMS_RUN_NO                        EMS_RUN_NO        98.136646
# DRIVER_ACTION                  DRIVER_ACTION        20.638563
# DRIVER_VISION                  DRIVER_VISION        20.666245
# PHYSICAL_CONDITION        PHYSICAL_CONDITION        20.581360
# PEDPEDAL_ACTION              PEDPEDAL_ACTION        98.141580
# PEDPEDAL_VISIBILITY      PEDPEDAL_VISIBILITY        98.145594
# PEDPEDAL_LOCATION          PEDPEDAL_LOCATION        98.141664
# BAC_RESULT                        BAC_RESULT        20.547072
# BAC_RESULT VALUE            BAC_RESULT VALUE        99.873468
# CELL_PHONE_USE                CELL_PHONE_USE        99.903240

# %%
perc = 20.0
min_count =  int(((100-perc)/100)*df.shape[0] + 1)
mod_df = df.dropna( axis=1, 
                thresh=min_count)
mod_df
