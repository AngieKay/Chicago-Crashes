# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/angie/Desktop/group_project/Chicago-Crashes/data/Traffic_Crashes_-_Vehicles.csv')
# Out:
# C:\Users\angie\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (19,21,40,41,42,44,48,49,50,53,55,58,59,61,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1107267 entries, 0 to 1107266
# Data columns (total 72 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   CRASH_UNIT_ID             1107267 non-null  int64
#  1   CRASH_RECORD_ID           1107267 non-null  object
#  2   RD_NO                     1097786 non-null  object
#  3   CRASH_DATE                1107267 non-null  object
#  4   UNIT_NO                   1107267 non-null  int64
#  5   UNIT_TYPE                 1105670 non-null  object
#  6   NUM_PASSENGERS            165920 non-null   float64
#  7   VEHICLE_ID                1081934 non-null  float64
#  8   CMRC_VEH_I                20475 non-null    object
#  9   MAKE                      1081929 non-null  object
#  10  MODEL                     1081786 non-null  object
#  11  LIC_PLATE_STATE           987487 non-null   object
#  12  VEHICLE_YEAR              905696 non-null   float64
#  13  VEHICLE_DEFECT            1081934 non-null  object
#  14  VEHICLE_TYPE              1081934 non-null  object
#  15  VEHICLE_USE               1081934 non-null  object
#  16  TRAVEL_DIRECTION          1081934 non-null  object
#  17  MANEUVER                  1081934 non-null  object
#  18  TOWED_I                   129495 non-null   object
#  19  FIRE_I                    852 non-null      object
#  20  OCCUPANT_CNT              1081934 non-null  float64
#  21  EXCEED_SPEED_LIMIT_I      2392 non-null     object
#  22  TOWED_BY                  95272 non-null    object
#  23  TOWED_TO                  59127 non-null    object
#  24  AREA_00_I                 41674 non-null    object
#  25  AREA_01_I                 288768 non-null   object
#  26  AREA_02_I                 185104 non-null   object
#  27  AREA_03_I                 104940 non-null   object
#  28  AREA_04_I                 108915 non-null   object
#  29  AREA_05_I                 166628 non-null   object
#  30  AREA_06_I                 168223 non-null   object
#  31  AREA_07_I                 147128 non-null   object
#  32  AREA_08_I                 179064 non-null   object
#  33  AREA_09_I                 52921 non-null    object
#  34  AREA_10_I                 76171 non-null    object
#  35  AREA_11_I                 150675 non-null   object
#  36  AREA_12_I                 148328 non-null   object
#  37  AREA_99_I                 118504 non-null   object
#  38  FIRST_CONTACT_POINT       1073691 non-null  object
#  39  CMV_ID                    11565 non-null    float64
#  40  USDOT_NO                  6717 non-null     object
#  41  CCMC_NO                   1474 non-null     object
#  42  ILCC_NO                   1068 non-null     object
#  43  COMMERCIAL_SRC            8172 non-null     object
#  44  GVWR                      6722 non-null     object
#  45  CARRIER_NAME              11079 non-null    object
#  46  CARRIER_STATE             10462 non-null    object
#  47  CARRIER_CITY              10274 non-null    object
#  48  HAZMAT_PLACARDS_I         235 non-null      object
#  49  HAZMAT_NAME               45 non-null       object
#  50  UN_NO                     429 non-null      object
#  51  HAZMAT_PRESENT_I          8560 non-null     object
#  52  HAZMAT_REPORT_I           8291 non-null     object
#  53  HAZMAT_REPORT_NO          1 non-null        object
#  54  MCS_REPORT_I              8349 non-null     object
#  55  MCS_REPORT_NO             6 non-null        object
#  56  HAZMAT_VIO_CAUSE_CRASH_I  8427 non-null     object
#  57  MCS_VIO_CAUSE_CRASH_I     8286 non-null     object
#  58  IDOT_PERMIT_NO            679 non-null      object
#  59  WIDE_LOAD_I               100 non-null      object
#  60  TRAILER1_WIDTH            2310 non-null     object
#  61  TRAILER2_WIDTH            264 non-null      object
#  62  TRAILER1_LENGTH           1907 non-null     float64
#  63  TRAILER2_LENGTH           50 non-null       float64
#  64  TOTAL_VEHICLE_LENGTH      2287 non-null     float64
#  65  AXLE_CNT                  3313 non-null     float64
#  66  VEHICLE_CONFIG            9641 non-null     object
#  67  CARGO_BODY_TYPE           9247 non-null     object
#  68  LOAD_TYPE                 8854 non-null     object
#  69  HAZMAT_OUT_OF_SERVICE_I   8052 non-null     object
#  70  MCS_OUT_OF_SERVICE_I      8273 non-null     object
#  71  HAZMAT_CLASS              799 non-null      object
# dtypes: float64(9), int64(2), object(61)
# memory usage: 608.2+ MB

# %%
perc = 20.0
min_count =  int(((100-perc)/100)*df.shape[0] + 1)
mod_df = df.dropna( axis=1, 
                thresh=min_count)

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

pd.set_option('display.max_rows', None)
missing_value_df
# Out:
#                                        column_name  percent_missing
# CRASH_UNIT_ID                        CRASH_UNIT_ID         0.000000
# CRASH_RECORD_ID                    CRASH_RECORD_ID         0.000000
# RD_NO                                        RD_NO         0.856252
# CRASH_DATE                              CRASH_DATE         0.000000
# UNIT_NO                                    UNIT_NO         0.000000
# UNIT_TYPE                                UNIT_TYPE         0.144229
# NUM_PASSENGERS                      NUM_PASSENGERS        85.015358
# VEHICLE_ID                              VEHICLE_ID         2.287885
# CMRC_VEH_I                              CMRC_VEH_I        98.150853
# MAKE                                          MAKE         2.288337
# MODEL                                        MODEL         2.301252
# LIC_PLATE_STATE                    LIC_PLATE_STATE        10.817626
# VEHICLE_YEAR                          VEHICLE_YEAR        18.204372
# VEHICLE_DEFECT                      VEHICLE_DEFECT         2.287885
# VEHICLE_TYPE                          VEHICLE_TYPE         2.287885
# VEHICLE_USE                            VEHICLE_USE         2.287885
# TRAVEL_DIRECTION                  TRAVEL_DIRECTION         2.287885
# MANEUVER                                  MANEUVER         2.287885
# TOWED_I                                    TOWED_I        88.304989
# FIRE_I                                      FIRE_I        99.923054
# OCCUPANT_CNT                          OCCUPANT_CNT         2.287885
# EXCEED_SPEED_LIMIT_I          EXCEED_SPEED_LIMIT_I        99.783973
# TOWED_BY                                  TOWED_BY        91.395752
# TOWED_TO                                  TOWED_TO        94.660096
# AREA_00_I                                AREA_00_I        96.236319
# AREA_01_I                                AREA_01_I        73.920653
# AREA_02_I                                AREA_02_I        83.282804
# AREA_03_I                                AREA_03_I        90.522611
# AREA_04_I                                AREA_04_I        90.163619
# AREA_05_I                                AREA_05_I        84.951416
# AREA_06_I                                AREA_06_I        84.807368
# AREA_07_I                                AREA_07_I        86.712509
# AREA_08_I                                AREA_08_I        83.828291
# AREA_09_I                                AREA_09_I        95.220575
# AREA_10_I                                AREA_10_I        93.120810
# AREA_11_I                                AREA_11_I        86.392171
# AREA_12_I                                AREA_12_I        86.604134
# AREA_99_I                                AREA_99_I        89.297613
# FIRST_CONTACT_POINT            FIRST_CONTACT_POINT         3.032331
# CMV_ID                                      CMV_ID        98.955536
# USDOT_NO                                  USDOT_NO        99.393371
# CCMC_NO                                    CCMC_NO        99.866879
# ILCC_NO                                    ILCC_NO        99.903546
# COMMERCIAL_SRC                      COMMERCIAL_SRC        99.261967
# GVWR                                          GVWR        99.392920
# CARRIER_NAME                          CARRIER_NAME        98.999428
# CARRIER_STATE                        CARRIER_STATE        99.055151
# CARRIER_CITY                          CARRIER_CITY        99.072130
# HAZMAT_PLACARDS_I                HAZMAT_PLACARDS_I        99.978777
# HAZMAT_NAME                            HAZMAT_NAME        99.995936
# UN_NO                                        UN_NO        99.961256
# HAZMAT_PRESENT_I                  HAZMAT_PRESENT_I        99.226925
# HAZMAT_REPORT_I                    HAZMAT_REPORT_I        99.251219
# HAZMAT_REPORT_NO                  HAZMAT_REPORT_NO        99.999910
# MCS_REPORT_I                          MCS_REPORT_I        99.245981
# MCS_REPORT_NO                        MCS_REPORT_NO        99.999458
# HAZMAT_VIO_CAUSE_CRASH_I  HAZMAT_VIO_CAUSE_CRASH_I        99.238937
# MCS_VIO_CAUSE_CRASH_I        MCS_VIO_CAUSE_CRASH_I        99.251671
# IDOT_PERMIT_NO                      IDOT_PERMIT_NO        99.938678
# WIDE_LOAD_I                            WIDE_LOAD_I        99.990969
# TRAILER1_WIDTH                      TRAILER1_WIDTH        99.791378
# TRAILER2_WIDTH                      TRAILER2_WIDTH        99.976158
# TRAILER1_LENGTH                    TRAILER1_LENGTH        99.827774
# TRAILER2_LENGTH                    TRAILER2_LENGTH        99.995484
# TOTAL_VEHICLE_LENGTH          TOTAL_VEHICLE_LENGTH        99.793455
# AXLE_CNT                                  AXLE_CNT        99.700795
# VEHICLE_CONFIG                      VEHICLE_CONFIG        99.129298
# CARGO_BODY_TYPE                    CARGO_BODY_TYPE        99.164881
# LOAD_TYPE                                LOAD_TYPE        99.200374
# HAZMAT_OUT_OF_SERVICE_I    HAZMAT_OUT_OF_SERVICE_I        99.272804
# MCS_OUT_OF_SERVICE_I          MCS_OUT_OF_SERVICE_I        99.252845
# HAZMAT_CLASS                          HAZMAT_CLASS        99.927840

# %%
mod_df['UNIT_NO'].value_counts()
# Out:
# 1          545913
# 2          514623
# 3           36269
# 4            7387
# 5            1958
# 6             642
# 7             249
# 8             102
# 9              50
# 10             23
# 0              16
# 11             12
# 12              7
# 13              4
# 14              4
# 15              3
# 16              2
# 18              1
# 17              1
# 3778035         1
# Name: UNIT_NO, dtype: int64
